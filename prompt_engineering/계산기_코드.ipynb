# %%
def calculator():
    print("간단한 계산기입니다. 두 숫자와 연산자를 입력하세요.")

    num1 = float(input("첫 번째 숫자를 입력하세요: "))
    operator = input("연산자를 입력하세요 (+, -, *, /): ")
    num2 = float(input("두 번째 숫자를 입력하세요: "))

    if operator == "+":
        result = num1 + num2
    elif operator == "-":
        result = num1 - num2
    elif operator == "*":
        result = num1 * num2
    elif operator == "/":
        if num2 != 0:
            result = num1 / num2
        else:
            return "0으로 나눌 수 없습니다."
    else:
        return "올바르지 않은 연산자입니다."

    return f"결과: {result}"

# 계산기 실행
result = calculator()
print(result)
# Out:
# 간단한 계산기입니다. 두 숫자와 연산자를 입력하세요.
# 첫 번째 숫자를 입력하세요: 45
# 연산자를 입력하세요 (+, -, *, /): +
# 두 번째 숫자를 입력하세요: 154
# 결과: 199.0

# %%
result = calculator()
print(result)
# Out:
# 간단한 계산기입니다. 두 숫자와 연산자를 입력하세요.
# 첫 번째 숫자를 입력하세요: 457487
# 연산자를 입력하세요 (+, -, *, /): /
# 두 번째 숫자를 입력하세요: 0
# 0으로 나눌 수 없습니다.
